# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt
import seaborn as sns

# %%
df = pd.read_csv("financial_loan.csv")

# %%
df
# Out:
#             id address_state application_type emp_length  \
# 0      1077430            GA       INDIVIDUAL   < 1 year
# 1      1072053            CA       INDIVIDUAL    9 years
# 2      1069243            CA       INDIVIDUAL    4 years
# 3      1041756            TX       INDIVIDUAL   < 1 year
# 4      1068350            IL       INDIVIDUAL  10+ years
# ...        ...           ...              ...        ...
# 38571   803452            NJ       INDIVIDUAL   < 1 year
# 38572   970377            NY       INDIVIDUAL    8 years
# 38573   875376            CA       INDIVIDUAL    5 years
# 38574   972997            NY       INDIVIDUAL    5 years
# 38575   682952            NY       INDIVIDUAL    4 years
#
#                              emp_title grade home_ownership  issue_date  \
# 0                                Ryder     C           RENT  11-02-2021
# 1                       MKC Accounting     E           RENT  01-01-2021
# ...

# %%
df.shape
# Out:
# (38576, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38576 entries, 0 to 38575
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     38576 non-null  int64
#  1   address_state          38576 non-null  object
#  2   application_type       38576 non-null  object
#  3   emp_length             38576 non-null  object
#  4   emp_title              37138 non-null  object
#  5   grade                  38576 non-null  object
#  6   home_ownership         38576 non-null  object
#  7   issue_date             38576 non-null  object
#  8   last_credit_pull_date  38576 non-null  object
#  9   last_payment_date      38576 non-null  object
#  10  loan_status            38576 non-null  object
#  11  next_payment_date      38576 non-null  object
#  12  member_id              38576 non-null  int64
#  13  purpose                38576 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# id                          0
# address_state               0
# application_type            0
# emp_length                  0
# emp_title                1438
# grade                       0
# home_ownership              0
# issue_date                  0
# last_credit_pull_date       0
# last_payment_date           0
# loan_status                 0
# next_payment_date           0
# member_id                   0
# purpose                     0
# sub_grade                   0
# term                        0
# verification_status         0
# annual_income               0
# dti                         0
# installment                 0
# int_rate                    0
# loan_amount                 0
# total_acc                   0
# total_payment               0
# dtype: int64

# %% [markdown]
# emp_title columns has 1438 missing values

# %%
df.columns
# Out:
# Index(['id', 'address_state', 'application_type', 'emp_length', 'emp_title',
#        'grade', 'home_ownership', 'issue_date', 'last_credit_pull_date',
#        'last_payment_date', 'loan_status', 'next_payment_date', 'member_id',
#        'purpose', 'sub_grade', 'term', 'verification_status', 'annual_income',
#        'dti', 'installment', 'int_rate', 'loan_amount', 'total_acc',
#        'total_payment'],
#       dtype='object')

# %%
# id columns has no issuse
df["id"].unique()
# Out:
# array([1077430, 1072053, 1069243, ...,  875376,  972997,  682952],
#       dtype=int64)

# %%
# address_state columns has no issuse
df["address_state"].unique()
# Out:
# array(['GA', 'CA', 'TX', 'IL', 'PA', 'FL', 'MI', 'RI', 'NY', 'MD', 'WI',
#        'NV', 'UT', 'WA', 'NH', 'HI', 'MA', 'OK', 'NJ', 'OH', 'AZ', 'CT',
#        'MN', 'CO', 'TN', 'VA', 'MO', 'DE', 'NM', 'LA', 'AR', 'KY', 'NC',
#        'SC', 'WV', 'KS', 'WY', 'OR', 'AL', 'VT', 'MS', 'DC', 'MT', 'SD',
#        'AK', 'IN', 'ME', 'ID', 'NE', 'IA'], dtype=object)

# %%
df["address_state"].nunique()
# Out:
# 50

# %%
# application_type columns has no issuse
df["application_type"].unique()
# Out:
# array(['INDIVIDUAL'], dtype=object)

# %%
df["application_type"].nunique()
# Out:
# 1

# %%
df["emp_length"].unique()
# Out:
# array(['< 1 year', '9 years', '4 years', '10+ years', '3 years',
#        '5 years', '1 year', '6 years', '2 years', '7 years', '8 years'],
#       dtype=object)

# %%
df["emp_length"].nunique()
# Out:
# 11

# %%
# changed the value "< 1 year" to "1 year" and "10+ year to 10 year"
df["emp_length"] = df["emp_length"].replace('< 1 year','1 year')
df["emp_length"] = df["emp_length"].replace('10+ years','10 years')

# %%
df["emp_length"].unique()
# Out:
# array(['1 year', '9 years', '4 years', '10 years', '3 years', '5 years',
#        '6 years', '2 years', '7 years', '8 years'], dtype=object)

# %%
df["emp_length"].nunique()
# Out:
# 10

# %%
df["emp_length"].isnull().sum()
# Out:
# 0

# %%
# added a new columns called "Loan_Tenure_years" which i have splited the values from "emp_length"
df["Loan_Tenure_years"] = df["emp_length"].apply(lambda x: x.split()[0]).astype(int)

# %%
df
# Out:
#             id address_state application_type emp_length  \
# 0      1077430            GA       INDIVIDUAL     1 year
# 1      1072053            CA       INDIVIDUAL    9 years
# 2      1069243            CA       INDIVIDUAL    4 years
# 3      1041756            TX       INDIVIDUAL     1 year
# 4      1068350            IL       INDIVIDUAL   10 years
# ...        ...           ...              ...        ...
# 38571   803452            NJ       INDIVIDUAL     1 year
# 38572   970377            NY       INDIVIDUAL    8 years
# 38573   875376            CA       INDIVIDUAL    5 years
# 38574   972997            NY       INDIVIDUAL    5 years
# 38575   682952            NY       INDIVIDUAL    4 years
#
#                              emp_title grade home_ownership  issue_date  \
# 0                                Ryder     C           RENT  11-02-2021
# 1                       MKC Accounting     E           RENT  01-01-2021
# ...

# %%
df["Loan_Tenure_years"].isnull().sum()
# Out:
# 0

# %%
df["Loan_Tenure_years"].unique()
# Out:
# array([ 1,  9,  4, 10,  3,  5,  6,  2,  7,  8])

# %%
df.drop(columns ="Loan_Tenure",inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'address_state', 'application_type', 'emp_length', 'emp_title',
#        'grade', 'home_ownership', 'issue_date', 'last_credit_pull_date',
#        'last_payment_date', 'loan_status', 'next_payment_date', 'member_id',
#        'purpose', 'sub_grade', 'term', 'verification_status', 'annual_income',
#        'dti', 'installment', 'int_rate', 'loan_amount', 'total_acc',
#        'total_payment', 'Loan_Tenure_years'],
#       dtype='object')

# %%
df['emp_title'].unique()
# Out:
# array(['Ryder', 'MKC Accounting', 'Chemat Technology Inc', ...,
#        'Anaheim Regional Medical Center', 'Brooklyn Radiology',
#        'Allen Edmonds'], dtype=object)

# %%
df['emp_title'].nunique()
# Out:
# 28525

# %%
df['emp_title'].isnull().sum()
# Out:
# 1438

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (37138, 25)

# %%
df
# Out:
#             id address_state application_type emp_length  \
# 0      1077430            GA       INDIVIDUAL     1 year
# 1      1072053            CA       INDIVIDUAL    9 years
# 2      1069243            CA       INDIVIDUAL    4 years
# 3      1041756            TX       INDIVIDUAL     1 year
# 4      1068350            IL       INDIVIDUAL   10 years
# ...        ...           ...              ...        ...
# 38571   803452            NJ       INDIVIDUAL     1 year
# 38572   970377            NY       INDIVIDUAL    8 years
# 38573   875376            CA       INDIVIDUAL    5 years
# 38574   972997            NY       INDIVIDUAL    5 years
# 38575   682952            NY       INDIVIDUAL    4 years
#
#                              emp_title grade home_ownership  issue_date  \
# 0                                Ryder     C           RENT  11-02-2021
# 1                       MKC Accounting     E           RENT  01-01-2021
# ...

# %%
df['emp_title'].isnull().sum()
# Out:
# 0

# %%
df['emp_title'].duplicated().sum()
# Out:
# 8613

# %%
df['emp_title'].unique()
# Out:
# array(['Ryder', 'MKC Accounting', 'Chemat Technology Inc', ...,
#        'Anaheim Regional Medical Center', 'Brooklyn Radiology',
#        'Allen Edmonds'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37138 entries, 0 to 38575
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     37138 non-null  int64
#  1   address_state          37138 non-null  object
#  2   application_type       37138 non-null  object
#  3   emp_length             37138 non-null  object
#  4   emp_title              37138 non-null  object
#  5   grade                  37138 non-null  object
#  6   home_ownership         37138 non-null  object
#  7   issue_date             37138 non-null  object
#  8   last_credit_pull_date  37138 non-null  object
#  9   last_payment_date      37138 non-null  object
#  10  loan_status            37138 non-null  object
#  11  next_payment_date      37138 non-null  object
#  12  member_id              37138 non-null  int64
#  13  purpose                37138 non-null  object
# ...

# %%
# "Grade" columns has no issuse
df["grade"].unique()
# Out:
# array(['C', 'E', 'B', 'A', 'D', 'F', 'G'], dtype=object)

# %%
df["grade"].isnull().sum()
# Out:
# 0

# %%
# "Home_Ownership" has no issuse
df["home_ownership"].unique()
# Out:
# array(['RENT', 'MORTGAGE', 'OWN', 'OTHER', 'NONE'], dtype=object)

# %%
df[df["home_ownership"]=='NONE']
# Out:
#           id address_state application_type emp_length emp_title grade  \
# 7744  231321            VA       INDIVIDUAL    5 years       ups     A
#
#      home_ownership  issue_date last_credit_pull_date last_payment_date  ...  \
# 7744           NONE  08-01-2021            11-01-2021        11-02-2021  ...
#
#             term verification_status  annual_income     dti installment  \
# 7744   36 months        Not Verified        22200.0  0.0524      312.22
#
#      int_rate loan_amount  total_acc  total_payment  Loan_Tenure_years
# 7744   0.0775       10000         22          11240                  5
#
# [1 rows x 25 columns]

# %%
df[df["home_ownership"]=='OTHER']
# Out:
#            id address_state application_type emp_length  \
# 273    366128            CA       INDIVIDUAL    5 years
# 811    386587            NJ       INDIVIDUAL     1 year
# 1814   379227            CA       INDIVIDUAL    5 years
# 2600   347390            TX       INDIVIDUAL   10 years
# 2601   364148            CO       INDIVIDUAL     1 year
# ...       ...           ...              ...        ...
# 36598  392602            OH       INDIVIDUAL    4 years
# 36599  396522            AZ       INDIVIDUAL     1 year
# 36600  388005            FL       INDIVIDUAL    4 years
# 36601  376036            CA       INDIVIDUAL     1 year
# 38258  422880            MN       INDIVIDUAL    2 years
#
#                        emp_title grade home_ownership  issue_date  \
# 273       Hacienda La Puente USD     A          OTHER  08-12-2021
# 811    Dept of Homeland Security     C          OTHER  09-04-2021
# 1814                   Entar.com     B          OTHER  09-02-2021
# ...

# %%
df["home_ownership"].mode()
# Out:
# 0    RENT
# Name: home_ownership, dtype: object

# %%
df["home_ownership"] = df["home_ownership"].replace('NONE','RENT')

# %%
df["home_ownership"].unique()
# Out:
# array(['RENT', 'MORTGAGE', 'OWN', 'OTHER'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37138 entries, 0 to 38575
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     37138 non-null  int64
#  1   address_state          37138 non-null  object
#  2   application_type       37138 non-null  object
#  3   emp_length             37138 non-null  object
#  4   emp_title              37138 non-null  object
#  5   grade                  37138 non-null  object
#  6   home_ownership         37138 non-null  object
#  7   issue_date             37138 non-null  object
#  8   last_credit_pull_date  37138 non-null  object
#  9   last_payment_date      37138 non-null  object
#  10  loan_status            37138 non-null  object
#  11  next_payment_date      37138 non-null  object
#  12  member_id              37138 non-null  int64
#  13  purpose                37138 non-null  object
# ...

# %%
df["issue_date"] = pd.to_datetime(df["issue_date"], format='%d-%m-%Y')

# %%
df["issue_date"].isnull().sum()
# Out:
# 0

# %%
df["last_credit_pull_date"] = pd.to_datetime(df["last_credit_pull_date"] , format='%d-%m-%Y')

# %%
df["last_payment_date"] = pd.to_datetime(df["last_payment_date"] , format='%d-%m-%Y')

# %%
df["last_credit_pull_date"].isnull().sum()
# Out:
# 0

# %%
df["last_payment_date"].isnull().sum()
# Out:
# 0

# %%
df
# Out:
#             id address_state application_type emp_length  \
# 0      1077430            GA       INDIVIDUAL     1 year
# 1      1072053            CA       INDIVIDUAL    9 years
# 2      1069243            CA       INDIVIDUAL    4 years
# 3      1041756            TX       INDIVIDUAL     1 year
# 4      1068350            IL       INDIVIDUAL   10 years
# ...        ...           ...              ...        ...
# 38571   803452            NJ       INDIVIDUAL     1 year
# 38572   970377            NY       INDIVIDUAL    8 years
# 38573   875376            CA       INDIVIDUAL    5 years
# 38574   972997            NY       INDIVIDUAL    5 years
# 38575   682952            NY       INDIVIDUAL    4 years
#
#                              emp_title grade home_ownership issue_date  \
# 0                                Ryder     C           RENT 2021-02-11
# 1                       MKC Accounting     E           RENT 2021-01-01
# ...

# %%
df["term"].unique()
# Out:
# array([' 60 months', ' 36 months'], dtype=object)

# %%
df["term"].nunique()
# Out:
# 2

# %%
df["term"].isnull().sum()
# Out:
# 0

# %%
df["Loan_Month"] = df["term"].apply(lambda x: x.split()[0])

# %%
df["term"].apply(lambda x: x.split()[0])
# Out:
# 0        60
# 1        36
# 2        36
# 3        60
# 4        36
#          ..
# 38571    60
# 38572    60
# 38573    60
# 38574    60
# 38575    60
# Name: term, Length: 37138, dtype: object

# %%
df
# Out:
#             id address_state application_type emp_length  \
# 0      1077430            GA       INDIVIDUAL     1 year
# 1      1072053            CA       INDIVIDUAL    9 years
# 2      1069243            CA       INDIVIDUAL    4 years
# 3      1041756            TX       INDIVIDUAL     1 year
# 4      1068350            IL       INDIVIDUAL   10 years
# ...        ...           ...              ...        ...
# 38571   803452            NJ       INDIVIDUAL     1 year
# 38572   970377            NY       INDIVIDUAL    8 years
# 38573   875376            CA       INDIVIDUAL    5 years
# 38574   972997            NY       INDIVIDUAL    5 years
# 38575   682952            NY       INDIVIDUAL    4 years
#
#                              emp_title grade home_ownership issue_date  \
# 0                                Ryder     C           RENT 2021-02-11
# 1                       MKC Accounting     E           RENT 2021-01-01
# ...

# %%
df.columns
# Out:
# Index(['id', 'address_state', 'application_type', 'emp_length', 'emp_title',
#        'grade', 'home_ownership', 'issue_date', 'last_credit_pull_date',
#        'last_payment_date', 'loan_status', 'next_payment_date', 'member_id',
#        'purpose', 'sub_grade', 'term', 'verification_status', 'annual_income',
#        'dti', 'installment', 'int_rate', 'loan_amount', 'total_acc',
#        'total_payment', 'Loan_Tenure_years', 'Loan_Month'],
#       dtype='object')

# %%
df['loan_status'].unique()
# Out:
# array(['Charged Off', 'Fully Paid', 'Current'], dtype=object)

# %%
df['loan_status'].isnull().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37138 entries, 0 to 38575
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     37138 non-null  int64
#  1   address_state          37138 non-null  object
#  2   application_type       37138 non-null  object
#  3   emp_length             37138 non-null  object
#  4   emp_title              37138 non-null  object
#  5   grade                  37138 non-null  object
#  6   home_ownership         37138 non-null  object
#  7   issue_date             37138 non-null  datetime64[ns]
#  8   last_credit_pull_date  37138 non-null  datetime64[ns]
#  9   last_payment_date      37138 non-null  datetime64[ns]
#  10  loan_status            37138 non-null  object
#  11  next_payment_date      37138 non-null  datetime64[ns]
#  12  member_id              37138 non-null  int64
#  13  purpose                37138 non-null  object
# ...

# %%
df["next_payment_date"] = pd.to_datetime(df["next_payment_date"] , format='%d-%m-%Y')

# %%
df["purpose"].unique()
# Out:
# array(['car', 'credit card', 'Debt consolidation', 'educational',
#        'home improvement', 'house', 'major purchase', 'medical', 'moving',
#        'other', 'renewable_energy', 'small business', 'vacation',
#        'wedding'], dtype=object)

# %%
df["sub_grade"].unique()
# Out:
# array(['C4', 'E1', 'C5', 'B2', 'A1', 'C3', 'C2', 'A4', 'A5', 'B5', 'B4',
#        'B3', 'B1', 'A2', 'A3', 'D4', 'D2', 'C1', 'D3', 'D1', 'E3', 'F1',
#        'E2', 'E5', 'D5', 'E4', 'F2', 'G3', 'F3', 'G1', 'F4', 'G4', 'G2',
#        'F5', 'G5'], dtype=object)

# %%
df["verification_status"].unique()
# Out:
# array(['Source Verified', 'Not Verified', 'Verified'], dtype=object)

# %%
df["verification_status"].isnull().sum()
# Out:
# 0

# %%
df[df["verification_status"]=='Source Verified']
# Out:
#             id address_state application_type emp_length  \
# 0      1077430            GA       INDIVIDUAL     1 year
# 1      1072053            CA       INDIVIDUAL    9 years
# 3      1041756            TX       INDIVIDUAL     1 year
# 7      1066424            PA       INDIVIDUAL   10 years
# 15     1060995            RI       INDIVIDUAL     1 year
# ...        ...           ...              ...        ...
# 38566  1007647            VA       INDIVIDUAL     1 year
# 38567  1020423            GA       INDIVIDUAL     1 year
# 38568   792945            IL       INDIVIDUAL    3 years
# 38569   844956            VA       INDIVIDUAL    2 years
# 38570   841271            CT       INDIVIDUAL     1 year
#
#                                       emp_title grade home_ownership  \
# 0                                         Ryder     C           RENT
# 1                                MKC Accounting     E           RENT
# 3                           barnes distribution     B       MORTGAGE
# ...

# %%
df[df["verification_status"]=='Verified']
# Out:
#             id address_state application_type emp_length  \
# 4      1068350            IL       INDIVIDUAL   10 years
# 6      1067441            TX       INDIVIDUAL   10 years
# 8      1065254            FL       INDIVIDUAL   10 years
# 16     1046507            TX       INDIVIDUAL     1 year
# 18     1059497            FL       INDIVIDUAL   10 years
# ...        ...           ...              ...        ...
# 38571   803452            NJ       INDIVIDUAL     1 year
# 38572   970377            NY       INDIVIDUAL    8 years
# 38573   875376            CA       INDIVIDUAL    5 years
# 38574   972997            NY       INDIVIDUAL    5 years
# 38575   682952            NY       INDIVIDUAL    4 years
#
#                              emp_title grade home_ownership issue_date  \
# 4                        J&J Steel Inc     A       MORTGAGE 2021-01-01
# 6                    American Airlines     C       MORTGAGE 2021-11-19
# ...

# %%
df.columns
# Out:
# Index(['id', 'address_state', 'application_type', 'emp_length', 'emp_title',
#        'grade', 'home_ownership', 'issue_date', 'last_credit_pull_date',
#        'last_payment_date', 'loan_status', 'next_payment_date', 'member_id',
#        'purpose', 'sub_grade', 'term', 'verification_status', 'annual_income',
#        'dti', 'installment', 'int_rate', 'loan_amount', 'total_acc',
#        'total_payment', 'Loan_Tenure_years', 'Loan_Month'],
#       dtype='object')

# %%
df['annual_income'].describe()
# Out:
# count    3.713800e+04
# mean     6.927908e+04
# std      6.423341e+04
# min      4.000000e+03
# 25%      4.160000e+04
# 50%      6.000000e+04
# 75%      8.300000e+04
# max      6.000000e+06
# Name: annual_income, dtype: float64

# %%
df['dti'].describe()
# Out:
# count    37138.000000
# mean         0.133966
# std          0.066529
# min          0.000000
# 25%          0.083100
# 50%          0.135000
# 75%          0.186500
# max          0.299900
# Name: dti, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37138 entries, 0 to 38575
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     37138 non-null  int64
#  1   address_state          37138 non-null  object
#  2   application_type       37138 non-null  object
#  3   emp_length             37138 non-null  object
#  4   emp_title              37138 non-null  object
#  5   grade                  37138 non-null  object
#  6   home_ownership         37138 non-null  object
#  7   issue_date             37138 non-null  datetime64[ns]
#  8   last_credit_pull_date  37138 non-null  datetime64[ns]
#  9   last_payment_date      37138 non-null  datetime64[ns]
#  10  loan_status            37138 non-null  object
#  11  next_payment_date      37138 non-null  datetime64[ns]
#  12  member_id              37138 non-null  int64
#  13  purpose                37138 non-null  object
# ...

# %%
df["installment"].describe()
# Out:
# count    37138.000000
# mean       326.025746
# std        207.432894
# min         16.080000
# 25%        168.677500
# 50%        283.280000
# 75%        431.845000
# max       1305.190000
# Name: installment, dtype: float64

# %%
df.rename(columns = {"installment":"installment_amount"},inplace=True)

# %%
df
# Out:
#             id address_state application_type emp_length  \
# 0      1077430            GA       INDIVIDUAL     1 year
# 1      1072053            CA       INDIVIDUAL    9 years
# 2      1069243            CA       INDIVIDUAL    4 years
# 3      1041756            TX       INDIVIDUAL     1 year
# 4      1068350            IL       INDIVIDUAL   10 years
# ...        ...           ...              ...        ...
# 38571   803452            NJ       INDIVIDUAL     1 year
# 38572   970377            NY       INDIVIDUAL    8 years
# 38573   875376            CA       INDIVIDUAL    5 years
# 38574   972997            NY       INDIVIDUAL    5 years
# 38575   682952            NY       INDIVIDUAL    4 years
#
#                              emp_title grade home_ownership issue_date  \
# 0                                Ryder     C           RENT 2021-02-11
# 1                       MKC Accounting     E           RENT 2021-01-01
# ...

# %%
df["int_rate"].describe()
# Out:
# count    37138.000000
# mean         0.120540
# std          0.037169
# min          0.054200
# 25%          0.093200
# 50%          0.118600
# 75%          0.145900
# max          0.244000
# Name: int_rate, dtype: float64

# %%
df["loan_amount"].describe()
# Out:
# count    37138.000000
# mean     11279.596370
# std       7418.277857
# min        500.000000
# 25%       5600.000000
# 50%      10000.000000
# 75%      15000.000000
# max      35000.000000
# Name: loan_amount, dtype: float64

# %%
df["total_acc"].describe()
# Out:
# count    37138.000000
# mean        22.180704
# std         11.386043
# min          2.000000
# 25%         14.000000
# 50%         21.000000
# 75%         29.000000
# max         90.000000
# Name: total_acc, dtype: float64

# %%
df["total_payment"].describe()
# Out:
# count    37138.000000
# mean     12267.320588
# std       9017.266703
# min         34.000000
# 25%       5657.000000
# 50%      10072.000000
# 75%      16652.000000
# max      58564.000000
# Name: total_payment, dtype: float64

# %%
df.to_excel("Loan.xlsx")

# %%
df
# Out:
#             id address_state application_type emp_length  \
# 0      1077430            GA       INDIVIDUAL     1 year
# 1      1072053            CA       INDIVIDUAL    9 years
# 2      1069243            CA       INDIVIDUAL    4 years
# 3      1041756            TX       INDIVIDUAL     1 year
# 4      1068350            IL       INDIVIDUAL   10 years
# ...        ...           ...              ...        ...
# 38571   803452            NJ       INDIVIDUAL     1 year
# 38572   970377            NY       INDIVIDUAL    8 years
# 38573   875376            CA       INDIVIDUAL    5 years
# 38574   972997            NY       INDIVIDUAL    5 years
# 38575   682952            NY       INDIVIDUAL    4 years
#
#                              emp_title grade home_ownership issue_date  \
# 0                                Ryder     C           RENT 2021-02-11
# 1                       MKC Accounting     E           RENT 2021-01-01
# ...

# %%
df.columns
# Out:
# Index(['id', 'address_state', 'application_type', 'emp_length', 'emp_title',
#        'grade', 'home_ownership', 'issue_date', 'last_credit_pull_date',
#        'last_payment_date', 'loan_status', 'next_payment_date', 'member_id',
#        'purpose', 'sub_grade', 'term', 'verification_status', 'annual_income',
#        'dti', 'installment_amount', 'int_rate', 'loan_amount', 'total_acc',
#        'total_payment', 'Loan_Tenure_years', 'Loan_Month'],
#       dtype='object')

# %%
df["purpose"]
# Out:
# 0            car
# 1            car
# 2            car
# 3            car
# 4            car
#           ...
# 38571    wedding
# 38572    wedding
# 38573    wedding
# 38574    wedding
# 38575    wedding
# Name: purpose, Length: 37138, dtype: object

# %%
df["member_id"]
# Out:
# 0        1314167
# 1        1288686
# 2        1304116
# 3        1272024
# 4        1302971
#           ...
# 38571     992381
# 38572    1192039
# 38573    1089898
# 38574    1194971
# 38575     872217
# Name: member_id, Length: 37138, dtype: int64

# %%
df.drop(columns=['id','member_id','application_type','sub_grade','grade',])
# Set maximum number of columns to display
pd.set_option('display.max_columns', 30)

# %%
df.head()
# Out:
#         id address_state application_type emp_length              emp_title  \
# 0  1077430            GA       INDIVIDUAL     1 year                  Ryder
# 1  1072053            CA       INDIVIDUAL    9 years         MKC Accounting
# 2  1069243            CA       INDIVIDUAL    4 years  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL     1 year    barnes distribution
# 4  1068350            IL       INDIVIDUAL   10 years          J&J Steel Inc
#
#   grade home_ownership issue_date last_credit_pull_date last_payment_date  \
# 0     C           RENT 2021-02-11            2021-09-13        2021-04-13
# 1     E           RENT 2021-01-01            2021-12-14        2021-01-15
# 2     C           RENT 2021-01-05            2021-12-12        2021-01-09
# 3     B       MORTGAGE 2021-02-25            2021-12-12        2021-03-12
# 4     A       MORTGAGE 2021-01-01            2021-12-14        2021-01-15
#
# ...

# %%
df.drop(columns=['id','member_id','application_type','sub_grade','grade'],inplace=True)

# %%
df
# Out:
#       address_state emp_length                        emp_title  \
# 0                GA     1 year                            Ryder
# 1                CA    9 years                   MKC Accounting
# 2                CA    4 years            Chemat Technology Inc
# 3                TX     1 year              barnes distribution
# 4                IL   10 years                    J&J Steel Inc
# ...             ...        ...                              ...
# 38571            NJ     1 year         Joseph M Sanzari Company
# 38572            NY    8 years                        Swat Fame
# 38573            CA    5 years  Anaheim Regional Medical Center
# 38574            NY    5 years               Brooklyn Radiology
# 38575            NY    4 years                    Allen Edmonds
#
#       home_ownership issue_date last_credit_pull_date last_payment_date  \
# 0               RENT 2021-02-11            2021-09-13        2021-04-13
# ...

# %%
df.to_excel("Loan.xlsx")

# %%
df.shape
# Out:
# (37138, 21)

# %%
df["emp_length"].value_counts()
# Out:
# emp_length
# 10 years    8527
# 1 year      7316
# 2 years     4267
# 3 years     3975
# 4 years     3350
# 5 years     3168
# 6 years     2157
# 7 years     1721
# 8 years     1432
# 9 years     1225
# Name: count, dtype: int64

# %%
df["home_ownership"].value_counts()
# Out:
# home_ownership
# RENT        17859
# MORTGAGE    16542
# OWN          2641
# OTHER          96
# Name: count, dtype: int64

# %%
df['loan_status'].value_counts()
# Out:
# loan_status
# Fully Paid     31005
# Charged Off     5067
# Current         1066
# Name: count, dtype: int64

# %%
df["total_acc"].value_counts()
# Out:
# total_acc
# 17    1366
# 15    1362
# 16    1361
# 14    1357
# 20    1350
#       ...
# 78       1
# 72       1
# 81       1
# 76       1
# 73       1
# Name: count, Length: 80, dtype: int64

# %%
df1 =  pd.read_csv("financial_loan.csv")

# %%
df1
# Out:
#             id address_state application_type emp_length  \
# 0      1077430            GA       INDIVIDUAL   < 1 year
# 1      1072053            CA       INDIVIDUAL    9 years
# 2      1069243            CA       INDIVIDUAL    4 years
# 3      1041756            TX       INDIVIDUAL   < 1 year
# 4      1068350            IL       INDIVIDUAL  10+ years
# ...        ...           ...              ...        ...
# 38571   803452            NJ       INDIVIDUAL   < 1 year
# 38572   970377            NY       INDIVIDUAL    8 years
# 38573   875376            CA       INDIVIDUAL    5 years
# 38574   972997            NY       INDIVIDUAL    5 years
# 38575   682952            NY       INDIVIDUAL    4 years
#
#                              emp_title grade home_ownership  issue_date  \
# 0                                Ryder     C           RENT  11-02-2021
# 1                       MKC Accounting     E           RENT  01-01-2021
# ...

# %%
df1.drop(columns = ["emp_title","id","application_type","grade","sub_grade","member_id","total_acc"],inplace=True)

# %%
df1.columns
# Out:
# Index(['address_state', 'emp_length', 'home_ownership', 'issue_date',
#        'last_credit_pull_date', 'last_payment_date', 'loan_status',
#        'next_payment_date', 'purpose', 'term', 'verification_status',
#        'annual_income', 'dti', 'installment', 'int_rate', 'loan_amount',
#        'total_payment'],
#       dtype='object')

# %%
df1
# Out:
#       address_state emp_length home_ownership  issue_date  \
# 0                GA   < 1 year           RENT  11-02-2021
# 1                CA    9 years           RENT  01-01-2021
# 2                CA    4 years           RENT  05-01-2021
# 3                TX   < 1 year       MORTGAGE  25-02-2021
# 4                IL  10+ years       MORTGAGE  01-01-2021
# ...             ...        ...            ...         ...
# 38571            NJ   < 1 year       MORTGAGE  11-07-2021
# 38572            NY    8 years           RENT  11-10-2021
# 38573            CA    5 years           RENT  11-09-2021
# 38574            NY    5 years           RENT  11-10-2021
# 38575            NY    4 years           RENT  11-07-2021
#
#       last_credit_pull_date last_payment_date  loan_status next_payment_date  \
# 0                13-09-2021        13-04-2021  Charged Off        13-05-2021
# 1                14-12-2021        15-01-2021   Fully Paid        15-02-2021
# ...

# %%
df1["emp_length"] = df1["emp_length"].replace('< 1 year','1 year')
df1["emp_length"] = df1["emp_length"].replace('10+ years','10 years')

# %%
df1["Loan_Tenure_years"] = df1["emp_length"].apply(lambda x: x.split()[0]).astype(int)

# %%
df1["home_ownership"] = df1["home_ownership"].replace('NONE','RENT')

# %%
df1["issue_date"] = pd.to_datetime(df1["issue_date"], format='%d-%m-%Y')

# %%
df1["last_payment_date"] = pd.to_datetime(df1["last_payment_date"] , format='%d-%m-%Y')

# %%
df1["last_credit_pull_date"] = pd.to_datetime(df1["last_credit_pull_date"] , format='%d-%m-%Y')

# %%
df1["Loan_Month"] = df1["term"].apply(lambda x: x.split()[0]).astype(int)

# %%
df1["next_payment_date"] = pd.to_datetime(df1["next_payment_date"] , format='%d-%m-%Y')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38576 entries, 0 to 38575
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   address_state          38576 non-null  object
#  1   emp_length             38576 non-null  object
#  2   home_ownership         38576 non-null  object
#  3   issue_date             38576 non-null  datetime64[ns]
#  4   last_credit_pull_date  38576 non-null  datetime64[ns]
#  5   last_payment_date      38576 non-null  datetime64[ns]
#  6   loan_status            38576 non-null  object
#  7   next_payment_date      38576 non-null  datetime64[ns]
#  8   purpose                38576 non-null  object
#  9   term                   38576 non-null  object
#  10  verification_status    38576 non-null  object
#  11  annual_income          38576 non-null  float64
#  12  dti                    38576 non-null  float64
#  13  installment            38576 non-null  float64
# ...

# %%
df1.to_excel("Loan1.xlsx")

# %%
df1.head()
# Out:
#   address_state emp_length home_ownership issue_date last_credit_pull_date  \
# 0            GA     1 year           RENT 2021-02-11            2021-09-13
# 1            CA    9 years           RENT 2021-01-01            2021-12-14
# 2            CA    4 years           RENT 2021-01-05            2021-12-12
# 3            TX     1 year       MORTGAGE 2021-02-25            2021-12-12
# 4            IL   10 years       MORTGAGE 2021-01-01            2021-12-14
#
#   last_payment_date  loan_status next_payment_date purpose        term  \
# 0        2021-04-13  Charged Off        2021-05-13     car   60 months
# 1        2021-01-15   Fully Paid        2021-02-15     car   36 months
# 2        2021-01-09  Charged Off        2021-02-09     car   36 months
# 3        2021-03-12   Fully Paid        2021-04-12     car   60 months
# 4        2021-01-15   Fully Paid        2021-02-15     car   36 months
#
#   verification_status  annual_income     dti  installment  int_rate  \
# ...

# %%
df2 = pd.read_csv("financial_loan.csv")

# %%
df2
# Out:
#             id address_state application_type emp_length  \
# 0      1077430            GA       INDIVIDUAL   < 1 year
# 1      1072053            CA       INDIVIDUAL    9 years
# 2      1069243            CA       INDIVIDUAL    4 years
# 3      1041756            TX       INDIVIDUAL   < 1 year
# 4      1068350            IL       INDIVIDUAL  10+ years
# ...        ...           ...              ...        ...
# 38571   803452            NJ       INDIVIDUAL   < 1 year
# 38572   970377            NY       INDIVIDUAL    8 years
# 38573   875376            CA       INDIVIDUAL    5 years
# 38574   972997            NY       INDIVIDUAL    5 years
# 38575   682952            NY       INDIVIDUAL    4 years
#
#                              emp_title grade home_ownership  issue_date  \
# 0                                Ryder     C           RENT  11-02-2021
# 1                       MKC Accounting     E           RENT  01-01-2021
# ...

# %%
df2["emp_length"].value_counts()
# Out:
# emp_length
# 10+ years    8870
# < 1 year     4575
# 2 years      4382
# 3 years      4088
# 4 years      3428
# 5 years      3273
# 1 year       3229
# 6 years      2228
# 7 years      1772
# 8 years      1476
# 9 years      1255
# Name: count, dtype: int64

# %%
df1.columns
# Out:
# Index(['address_state', 'emp_length', 'home_ownership', 'issue_date',
#        'last_credit_pull_date', 'last_payment_date', 'loan_status',
#        'next_payment_date', 'purpose', 'term', 'verification_status',
#        'annual_income', 'dti', 'installment', 'int_rate', 'loan_amount',
#        'total_payment', 'Loan_Tenure_years', 'Loan_Month'],
#       dtype='object')

# %%
df["loan_status"].unique()
# Out:
# array(['Charged Off', 'Fully Paid', 'Current'], dtype=object)

# %%
df[df["loan_status"]=="Charged Off"]
# Out:
#       address_state emp_length                        emp_title  \
# 0                GA     1 year                            Ryder
# 2                CA    4 years            Chemat Technology Inc
# 8                FL   10 years                   Tech Data Corp
# 11               CA    3 years               myrvpartsplace.com
# 15               RI     1 year                          HSA-UWC
# ...             ...        ...                              ...
# 38488            MA    2 years             The Danvers Butchery
# 38489            NJ    2 years          Vericrest Financial Inc
# 38490            MA   10 years       Wendys OFH of New York Inc
# 38491            PA    2 years             Williams Residential
# 38492            CA   10 years  Hayward Unified School District
#
#       home_ownership issue_date last_credit_pull_date last_payment_date  \
# 0               RENT 2021-02-11            2021-09-13        2021-04-13
# ...

# %%
df[df["loan_status"]=="Fully Paid"]
# Out:
#       address_state emp_length                        emp_title  \
# 1                CA    9 years                   MKC Accounting
# 3                TX     1 year              barnes distribution
# 4                IL   10 years                    J&J Steel Inc
# 5                CA    3 years                   Studio 94 Corp
# 6                TX   10 years                American Airlines
# ...             ...        ...                              ...
# 38553            GA    4 years                        PILOT OIL
# 38554            NY    2 years  Guardian Life Insurance Company
# 38555            CA    4 years                     Advantage IT
# 38556            GA   10 years                us postal service
# 38557            MD    2 years                     T.Rowe Price
#
#       home_ownership issue_date last_credit_pull_date last_payment_date  \
# 1               RENT 2021-01-01            2021-12-14        2021-01-15
# ...

# %%
df[df["loan_status"]=="Current"]
# Out:
#       address_state emp_length                        emp_title  \
# 1448             GA    7 years           Golden Bell Management
# 1449             NV   10 years            Veoila Transportation
# 1450             MA   10 years                 atlantic express
# 1451             KS    2 years         Topeka Ear Nose & Throat
# 1452             NC    2 years      Hoist and Crane Systems Inc
# ...             ...        ...                              ...
# 38571            NJ     1 year         Joseph M Sanzari Company
# 38572            NY    8 years                        Swat Fame
# 38573            CA    5 years  Anaheim Regional Medical Center
# 38574            NY    5 years               Brooklyn Radiology
# 38575            NY    4 years                    Allen Edmonds
#
#       home_ownership issue_date last_credit_pull_date last_payment_date  \
# 1448        MORTGAGE 2021-09-11            2021-05-16        2021-05-16
# ...

# %%
df2.shape
# Out:
# (38576, 24)
